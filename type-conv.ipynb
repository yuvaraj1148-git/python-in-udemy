# %% [markdown]
# # Type Conversion Functions in Python
# # This script demonstrates various type conversion functions in Python.
# # the script includes examples of converting between different data types such as integers, floats, strings, and booleans.
# # in addition, it showcases the use of built-in functions like int(), float(), str(), and bool() for type conversion.
# # int() - Converts a value to an integer.
# # float() - Converts a value to a floating-point number.
# # str() - Converts a value to a string.
# # bool() - Converts a value to a boolean

# %% [markdown]
# # the int() function can convert a string representation of an integer to an actual integer, but it will raise a ValueError if the string is not a valid integer.
#
# # while converting a string that represents a binary number to an integer, you can use the int() function with base 2.
# # int() cannot convert a complex datatype

# %% [markdown]
# # in float as it is same as int()
# # it does not allow complex data type

# %% [markdown]
# # in boolean context, any non-zero number or non-empty string evaluates to True, while 0, False, and empty strings evaluate to False.

# %% [markdown]
# # complex() - Converts a value to a complex number.
# # The complex() function can convert a real number (int or float) to a complex number by adding an imaginary part of 0. It can also convert a string representation of a complex number to an actual complex number.
# # complex() function can be used to convert a number or a string to a complex number.

# %% [markdown]
# # str() can also be used to convert other data types to strings, including lists, tuples, and dictionaries.

# %%
a = 10
b = 3.14
c = "123"
d = True

print(int(a))     # Output: 10
print(int(b))     # Output: 3
print(int(c))     # Output: 123
print(int(d))     # Output: 1 (True is converted to 1)
print(int('0b1010', 2))  # Output: 10 (binary string to integer)

print(float(a))   # Output: 10.0
print(float(b))   # Output: 3.14
print(float(c))   # Output: 123.0
print(float(d))   # Output: 1.0 (True is converted to 1.0)

print(str(a))     # Output: "10"
print(str(b))     # Output: "3.14"
print(str(c))     # Output: "123"
print(str(d))     # Output: "True"
print(str(-1.5e3))  # Output: "-1500.0"
print(str([1, 2, 3]))  # Output: "[1, 2, 3]"
print(str((4, 5, 6)))  # Output: "(4, 5, 6)"
print(str({"a": 1, "b": 2}))  # Output: "{'a': 1, 'b': 2}"

print(bool(a))    # Output: True
print(bool(b))    # Output: True
print(bool(c))    # Output: True
print(bool(d))    # Output: True
print(bool(0))    # Output: False
print(bool(False))  # Output: False
print(bool(""))   # Output: False
print(bool(3+4j))  # Output: True (non-zero complex number is True)

print(complex(a))  # Output: (10+0j)
print(complex(b))  # Output: (3.14+0j)
print(complex(c))  # Output: (123+0j)
print(complex(d))  # Output: (1+0j)
print(complex("1+2j"))  # Output: (1+2j)
print(complex(False))  # Output: 0j (False is converted to 0j)
